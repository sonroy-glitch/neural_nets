# %%
import numpy as np
import nnfs
from nnfs.datasets import spiral_data
nnfs.init()

# %%
# developing a neural net with two layers of 16 neurons each with a relu activation function at each level 
#and a softmax activation funcation at then output 
class Dense_Layer:
    def __init__(self,n_inputs,n_neurons):
        self.weights=0.01*np.random.randn(n_inputs,n_neurons)
        self.biases=np.zeros(1,n_neurons)
    def forward(self,inputs):
        self.output=np.dot(inputs,self.weights)+self.biases

class Relu_Activation:
    def forward(self,inputs):
        self.output=np.maximum(0,inputs)

class Softmax_Activation:
    def forward(self,inputs):
        exponential_value=np.sum(inputs-np.max(inputs),axis=1 ,keepdims=True)
        self.output=exponential_value/np.sum(exponential_value,axis=1,keepdims=True)

# %%
X,y=spiral_data(samples=100,classes=16)
print(X.shape)
# Out:
# (1600, 2)

# %%
len(y.shape)==2
# Out:
# False

# %%
class Cross_Categorical_Entropy:
    def forward(self,inputs,y):
# Out:
#   Cell In[19], line 1
#     class Loss:
#                ^
# _IncompleteInputError: incomplete input

# %%
import matplotlib.pyplot as plt
x=np.arange(-10,11)
y=x**2
plt.plot(x,y)
##relu based function that creates a void numpy in nature. This gives out a data that provides with a non-linear 
#relationship with the input parameters and the model generated . This model generation gives a non-linear viewpoint
#to it via the ReLu Activation Function and finally we can slap on a softmax activatio fucntion at the end of it ,
#at the output neuron level.
